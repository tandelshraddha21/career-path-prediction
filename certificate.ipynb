# %%
import google.generativeai as genai
import tesserocr
from PIL import Image
from tesserocr import get_languages
get_languages('./eng.traineddata')
tesserocr.get_languages()
genai.configure(api_key="AIzaSyA2nWKIjn7iyCbX3yzYPWQjGmQMQSRdaCw")
model = genai.GenerativeModel("gemini-pro")

# %%
def _imageToText(imgPath):
    image = Image.open(imgPath)
    return tesserocr.image_to_text(image)


def checkIfCertifcateIsValid(certificatePath,name):
    options = [
  "information security",
  "shell programming",
  "r programming",
  "distro making",
  "machine learning",
  "full stack",
  "hadoop",
  "app development",
  "python",
]
    extracted_text = _imageToText(certificatePath)
    chat = model.start_chat(history=[])
    response = chat.send_message(f"{extracted_text}")
    response = chat.send_message(f"Is the certificate valid for {name}, just answer in True or False don't give any explaination, don't use markdown")
    if response.text == "True":
      response = chat.send_message(f"return only one appropriate category from the given list without any explainations {options}, return raw text instead of markdown")
      return (True,response.text)
    else:
       print(response.text)
       return (False,"Wrong Certificate Owner")

# %%
res = checkIfCertifcateIsValid("./sample.jpg","Anil Sahu")
print(res)
len(res)
# Out:
# (True, 'app development')
# 2

# %%
options = [
  "information security",
  "shell programming",
  "r programming",
  "distro making",
  "machine learning",
  "full stack",
  "hadoop",
  "app development",
  "python",
]

# %%
f"{options}"
# Out:
# "['information security', 'shell programming', 'r programming', 'distro making', 'machine learning', 'full stack', 'hadoop', 'app development', 'python']"
